# %%
# !python ../src/expansion.py
# Out:
# Cargando Entradas
# Desarrollando Diccionario
# Guardando Archivo

# %%
import feedparser
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords
import urllib.request
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import googletrans
import datetime
from termcolor import colored
from IPython.display import display, Markdown, Latex, HTML
import re
from IPython.display import Image
import pandas as pd
import json

# %%
# read file
with open("../data/data_expansion.json", 'r') as myfile:
    data=myfile.read()

# %%
pd.read_json(data)
# Out:
#                                                      Noticia_01  \
# current_date               [2020, 7, 1, 10, 49, 47, 2, 183, -1]
# date          {'date1': 'Wed, 01 Jul 2020 02:19:08 +0200', '...
# headline      Las pymes ven reducido el respaldo del seguro ...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          Las pymes ven reducido el respaldo del seguro ...
# title         Catalana Occidente recorta su cobertura de seg...
#
#                                                      Noticia_02  \
# current_date               [2020, 7, 1, 10, 49, 47, 2, 183, -1]
# date          {'date1': 'Wed, 01 Jul 2020 02:18:39 +0200', '...
# headline      La entidad quiere ampliar su base de clientes ...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          La entidad quiere ampliar su base de clientes ...
# title                           La apuesta de Intesa por España
#
#                                                      Noticia_03  \
# current_date               [2020, 7, 1, 10, 49, 48, 2, 183, -1]
# date          {'date1': 'Wed, 01 Jul 2020 01:10:48 +0200', '...
# headline
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     El Banco de España está convencido de que esta...
# text           El Banco de España está convencido de que est...
# title         El Covid tendrá un impacto fuerte en los balan...
#
#                                                      Noticia_04  \
# current_date               [2020, 7, 1, 10, 49, 49, 2, 183, -1]
# date          {'date1': 'Wed, 01 Jul 2020 01:08:55 +0200', '...
# headline      Las comisiones totales de la banca de inversió...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          Las comisiones totales de la banca de inversió...
# title         Los bancos de Wall Street ingresan comisiones ...
#
#                                                      Noticia_05  \
# current_date               [2020, 7, 1, 10, 49, 50, 2, 183, -1]
# date          {'date1': 'Wed, 01 Jul 2020 01:06:19 +0200', '...
# headline      El grupo nombra a un ex alto ejecutivo de Amaz...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          El grupo nombra a un ex alto ejecutivo de Amaz...
# title         Santander refuerza su organigrama para su tran...
#
#                                                      Noticia_06  \
# current_date               [2020, 7, 1, 10, 49, 50, 2, 183, -1]
# date          {'date1': 'Tue, 30 Jun 2020 23:12:11 +0200', '...
# headline      El 30 de junio era la fecha tope que tenían lo...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          El 30 de junio era la fecha tope que tenían lo...
# title         Nueva línea del ICO para facilitar la inversió...
#
#                                                      Noticia_07  \
# current_date               [2020, 7, 1, 10, 49, 51, 2, 183, -1]
# date          {'date1': 'Tue, 30 Jun 2020 19:04:11 +0200', '...
# headline      Cinco de los bancos más fuertes en el negocio ...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     Cinco de los bancos más fuertes en el negocio ...
# text          Cinco de los bancos más fuertes en el negocio ...
# title         Cinco bancos bajan los tipos del 'revolving' t...
#
#                                                      Noticia_08  \
# current_date               [2020, 7, 1, 10, 49, 51, 2, 183, -1]
# date          {'date1': 'Tue, 30 Jun 2020 18:52:00 +0200', '...
# headline      Banco Santander ha anunciado hoy el nombramien...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     Chávez, de nacionalidad estadounidense, aporta...
# text          Banco Santander ha anunciado hoy el nombramien...
# title         Santander ficha a tres expertos americanos  pa...
#
#                                                      Noticia_09  \
# current_date               [2020, 7, 1, 10, 49, 52, 2, 183, -1]
# date          {'date1': 'Tue, 30 Jun 2020 18:28:22 +0200', '...
# headline      Banco Sabadell ha cerrado la alianza estratégi...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     Banco Sabadell ha cerrado la alianza estratégi...
# text          Banco Sabadell ha cerrado la alianza estratégi...
# title         Banco Sabadell completa la venta de su gestora...
#
#                                                      Noticia_10  \
# current_date               [2020, 7, 1, 10, 49, 53, 2, 183, -1]
# date          {'date1': 'Tue, 30 Jun 2020 16:37:01 +0200', '...
# headline      Mapfre ofrece servicios de asistencia adaptado...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     Mapfre ofrece servicios de asistencia adaptado...
# text          Mapfre ofrece servicios de asistencia adaptado...
# title         Mapfre ofrece servicios de asistencia adaptado...
#
#                                     ...                          \
# current_date                        ...
# date                                ...
# headline                            ...
# img                                 ...
# link                                ...
# newspaper                           ...
# summarise                           ...
# text                                ...
# title                               ...
#
#                                                      Noticia_26  \
# current_date                [2020, 7, 1, 10, 50, 4, 2, 183, -1]
# date          {'date1': 'Sat, 27 Jun 2020 20:27:57 +0200', '...
# headline      Es hijo de Alfonso Cortina y no tendrá funcion...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          Es hijo de Alfonso Cortina y no tendrá funcion...
# title         El banco africano presidido por Alfredo Sáenz ...
#
#                                                      Noticia_27  \
# current_date                [2020, 7, 1, 10, 50, 4, 2, 183, -1]
# date          {'date1': 'Sat, 27 Jun 2020 20:27:45 +0200', '...
# headline      Ultima su lanzamiento apoyado en las redes soc...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     Aunque la funcionalidad de una entidad con lic...
# text          Ultima su lanzamiento apoyado en las redes soc...
# title         La 'fintech' de banca móvil Zelf llega a Españ...
#
#                                                      Noticia_28  \
# current_date                [2020, 7, 1, 10, 50, 5, 2, 183, -1]
# date          {'date1': 'Sat, 27 Jun 2020 20:27:39 +0200', '...
# headline      Charlotte Hogg, consejera delegada de Visa Eur...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/economia/2020/06/27/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          Charlotte Hogg, consejera delegada de Visa Eur...
# title         Visa: el cambio en los hábitos de pago será pe...
#
#                                                      Noticia_29  \
# current_date                [2020, 7, 1, 10, 50, 6, 2, 183, -1]
# date          {'date1': 'Sat, 27 Jun 2020 00:31:06 +0200', '...
# headline      Los semestrales de la banca estarán por debajo...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          Los semestrales de la banca estarán por debajo...
# title                         Un año de 24 meses para casi todo
#
#                                                      Noticia_30  \
# current_date                [2020, 7, 1, 10, 50, 6, 2, 183, -1]
# date          {'date1': 'Fri, 26 Jun 2020 10:27:21 +0200', '...
# headline      Las entidades financieras han inyectado ya 76....
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     Las entidades financieras han inyectado ya 76....
# text          Las entidades financieras han inyectado ya 76....
# title         La banca ha inyectado ya casi 77.000 millones ...
#
#                                                      Noticia_31  \
# current_date                [2020, 7, 1, 10, 50, 7, 2, 183, -1]
# date          {'date1': 'Fri, 26 Jun 2020 09:59:01 +0200', '...
# headline      La Comisión Europea pedirá abrir una investiga...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/tecnologia/...
# newspaper                                             expansion
# summarise     La Comisión Europea pedirá abrir una investiga...
# text          La Comisión Europea pedirá abrir una investiga...
# title         Bruselas pedirá investigar al regulador alemán...
#
#                                                      Noticia_32  \
# current_date                [2020, 7, 1, 10, 50, 8, 2, 183, -1]
# date          {'date1': 'Fri, 26 Jun 2020 07:43:27 +0200', '...
# headline      Helvetia Insurance ha cerrado la compra del 69...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise     Helvetia Insurance ha cerrado la compra del 69...
# text          Helvetia Insurance ha cerrado la compra del 69...
# title         Helvetia cierra la compra de Caser por 800 mil...
#
#                                                      Noticia_33  \
# current_date                [2020, 7, 1, 10, 50, 8, 2, 183, -1]
# date          {'date1': 'Fri, 26 Jun 2020 00:37:43 +0200', '...
# headline      Se trata de una plataforma que da a los client...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          Se trata de una plataforma que da a los client...
# title         ¿Por qué paga Mastercard mil millones por una ...
#
#                                                      Noticia_34  \
# current_date                [2020, 7, 1, 10, 50, 9, 2, 183, -1]
# date          {'date1': 'Thu, 25 Jun 2020 22:48:43 +0200', '...
# headline      El supervisor ultima una consulta pública sobr...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          El supervisor ultima una consulta pública sobr...
# title         Cómo quiere el BCE facilitar las fusiones banc...
#
#                                                      Noticia_35
# current_date               [2020, 7, 1, 10, 50, 10, 2, 183, -1]
# date          {'date1': 'Thu, 25 Jun 2020 20:52:29 +0200', '...
# headline      El sector se recupera en ingresos en lo peor d...
# img           https://e00-expansion.uecdn.es/assets/multimed...
# link          https://www.expansion.com/empresas/banca/2020/...
# newspaper                                             expansion
# summarise                                       Premium Content
# text          El sector se recupera en ingresos en lo peor d...
# title         ¿Qué bancos lideran la banca de inversión y se...
#
# [9 rows x 35 columns]

# %%
def print_news(i,expansion):
    print(colored((expansion[i]['newspaper']).upper(),'green',attrs=['bold']))
    print(colored(expansion[i]['date']['date1'],'grey',attrs=['bold']))
    print(colored(expansion[i]['title'],'magenta',attrs=['bold']))
    print(colored('Headline','blue'))
    print(expansion[i]['headline'])
    print(colored('Summarise','blue'))

    if expansion[i]['summarise'] != 'Premium Content':
        print(expansion[i]['summarise'])
    else:
        print(colored(expansion[i]['summarise'],'red'))
    print(colored('Text','blue'))
    print(expansion[i]['text'])
    url = expansion[i]['img']
    display(Image(url=url,width=500))
    display(Markdown('<a href="'+expansion[i]['link']+'">Link</a>'))
    print('\n')

# %%
data = json.loads(data)

# %%
print_news(i='Noticia_08',expansion=data)
# Out:
# EXPANSION
# Tue, 30 Jun 2020 18:52:00 +0200
# Santander ficha a tres expertos americanos  para su  transformación digital
# Headline
# Banco Santander ha anunciado hoy el nombramiento de tres expertos en tecnología para impulsar su estrategia y transformación digital. Se trata de tres estadounidenses que proceden de Goldman, de Amazon y de la firma de servicios profesionales Cognizant.
# Summarise
# Chávez, de nacionalidad estadounidense, aporta una amplia experiencia en el sector financiero tras haber trabajado veinte años en Goldman Sachs, donde fue socio desde 2006 y miembro del comité de dirección desde 2012, hasta que abandonó la entidad a final de 2019.
# Además, Banco Santander nombrará a Sebastian Gunningham presidente de Santander Consumer Finance y vicepresidente de Openbank, sujeto a la aprobación regulatoria, y también será asesor sénior de la presidenta en tecnología.
