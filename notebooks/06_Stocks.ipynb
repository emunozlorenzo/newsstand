# %%
import yfinance as yf

# %%
bbva = yf.Ticker("BBVA.MC")
# get historical market data
hist_bbva = bbva.history(period="6mo")
hist_bbva.tail()
hist_bbva[['Close']].plot();

# %%
import pandas as pd
hist_bbva['Date']= pd.to_datetime(hist_bbva.index.values, format='%Y-%m-%d')

# %%
hist_bbva["DateString"] = hist_bbva["Date"].dt.strftime("%Y-%m-%d")

# %%
hist_bbva
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits  \
# Date
# 2020-01-21  4.4729  4.5084  4.4597  4.4923  35627364        0.0             0
# 2020-01-22  4.4918  4.5018  4.4251  4.4450  15589639        0.0             0
# 2020-01-23  4.4507  4.4833  4.3816  4.4128  30744031        0.0             0
# 2020-01-24  4.4630  4.4904  4.3556  4.3589  16467529        0.0             0
# 2020-01-27  4.3092  4.3390  4.2548  4.2875  19359016        0.0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-07-14  3.1790  3.2070  3.1170  3.1690  25788558        0.0             0
# 2020-07-15  3.2050  3.2830  3.1090  3.2500  25052616        0.0             0
# 2020-07-16  3.2500  3.2830  3.2160  3.2620  18978272        0.0             0
# 2020-07-17  3.2630  3.2650  3.1780  3.2160  25230197        0.0             0
# 2020-07-21  3.2300  3.3190  3.1630  3.1830  20638470        0.0             0
#
# ...

# %%
san = yf.Ticker("SAN.MC")
# get historical market data
hist_san = san.history(period="6mo")
hist_san.tail()
hist_san[['Close']].plot();

# %%
hist_san.tail()
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-07-14  2.2350  2.2445  2.1915  2.2240  40772281        0.0             0
# 2020-07-15  2.2425  2.2985  2.1765  2.2670  80229768        0.0             0
# 2020-07-16  2.2640  2.2920  2.2365  2.2605  36430818        0.0             0
# 2020-07-17  2.2520  2.2590  2.1885  2.2150  73177683        0.0             0
# 2020-07-21  2.2285  2.3125  2.1845  2.1975  70237922        0.0             0
